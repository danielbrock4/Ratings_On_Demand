# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px
import os

# %%
# ridge_test_results = r'static/ridge_test_results.csv'

# %%
ridge_test_results  = os.path.join("static" , "ridge_test_results.csv")

# %%
clean_comp_results = pd.read_csv(ridge_test_results, low_memory=False)
clean_comp_results.head()
# Out:
#                         Title  Actual Rating  Predicted Rating  Difference  \
# 0                Side Effects            7.1              6.56       -0.54
# 1      The Lego Ninjago Movie            6.0              6.49        0.49
# 2  A Merry Friggin' Christmas            5.1              5.81        0.71
# 3            Meet the Fockers            6.3              6.24       -0.06
# 4       The Last Witch Hunter            6.0              5.65       -0.35
#
#    Accuracy   Votes  Title Length  Month                         Genre  \
# 0     92.44  177680            19      5         Crime, Drama, Mystery
# 1     91.77   21770            22     10  Animation, Action, Adventure
# 2     85.99    5772            17     11                 Comedy, Drama
# 3     99.00  249128            19      2               Comedy, Romance
# 4     94.10   92948            54     10    Action, Adventure, Fantasy
#
#    Duration (min)  Budget (mm)  Oscar Nominated Actors  is_oscar_directed  \
# 0             106           30                       2                  1
# 1             101           70                       0                  0
# 2              88            5                       0                  0
# 3             115           80                       1                  0
# 4             106           90                       0                  0
#
#   MPAA Rating
# 0           R
# 1          PG
# 2       PG-13
# 3       PG-13
# 4       PG-13

# %%
df = clean_comp_results
fig = px.scatter(df, x="Predicted Rating", y="Actual Rating", trendline="ols", hover_data=['Accuracy','Title', 'Genre' , 'Duration (min)' , 'Budget (mm)' , 'MPAA Rating' ])
fig.show()
