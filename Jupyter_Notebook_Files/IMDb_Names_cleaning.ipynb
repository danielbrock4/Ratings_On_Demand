# %%
# importing libraries to use
import pandas as pd

# %%
# Create the path to IMDB Names
resources_folder = r'Resources/'
IMDb_file = resources_folder + 'IMDb_Names.csv'
# Reading the csv as a Panda dataframe
IMDb_Names_df = pd.read_csv(IMDb_file, low_memory=False)
IMDb_Names_df.head()
# Out:
#   imdb_name_id             name               birth_name  height  \
# 0    nm0000001     Fred Astaire  Frederic Austerlitz Jr.   177.0
# 1    nm0000002    Lauren Bacall        Betty Joan Perske   174.0
# 2    nm0000003  Brigitte Bardot          Brigitte Bardot   166.0
# 3    nm0000004     John Belushi        John Adam Belushi   170.0
# 4    nm0000005   Ingmar Bergman     Ernst Ingmar Bergman   179.0
#
#                                                  bio  \
# 0  Fred Astaire was born in Omaha, Nebraska, to J...
# 1  Lauren Bacall was born Betty Joan Perske on Se...
# 2  Brigitte Bardot was born on September 28, 1934...
# 3  John Belushi was born in Chicago, Illinois, US...
# 4  Ernst Ingmar Bergman was born July 14, 1918, t...
#
#                                        birth_details date_of_birth  \
# 0               May 10, 1899 in Omaha, Nebraska, USA    1899-05-10
# 1  September 16, 1924 in The Bronx, New York City...    1924-09-16
# ...

# %%
# check the columns
IMDb_Names_df.columns.tolist()
# Out:
# ['imdb_name_id',
#  'name',
#  'birth_name',
#  'height',
#  'bio',
#  'birth_details',
#  'date_of_birth',
#  'place_of_birth',
#  'death_details',
#  'date_of_death',
#  'place_of_death',
#  'reason_of_death',
#  'spouses_string',
#  'spouses',
#  'divorces',
#  'spouses_with_children',
#  'children']

# %%
# keep only the ones we are going to use
IMDb_Names_df = IMDb_Names_df[
['imdb_name_id',
 'name',
 'date_of_birth',
 'date_of_death',
 ]
]
IMDb_Names_df.head()
# Out:
#   imdb_name_id             name date_of_birth date_of_death
# 0    nm0000001     Fred Astaire    1899-05-10    1987-06-22
# 1    nm0000002    Lauren Bacall    1924-09-16    2014-08-12
# 2    nm0000003  Brigitte Bardot    1934-09-28           NaN
# 3    nm0000004     John Belushi    1949-01-24    1982-03-05
# 4    nm0000005   Ingmar Bergman    1918-07-14    2007-07-30

# %%
# how many records do we have
IMDb_Names_df.count()
# Out:
# imdb_name_id     297705
# name             297705
# date_of_birth    110612
# date_of_death     39933
# dtype: int64

# %%
# we have some discrepancies with the date of birth and date of death 
# columns but we are keeping them cause we dont want to lose
# the name of actor/actress...

# %%
# Check for null under an entire DataFrame 
IMDb_Names_df.isnull().sum()
# Out:
# imdb_name_id          0
# name                  0
# date_of_birth    187093
# date_of_death    257772
# dtype: int64

# %%
# save final dataframe to a csv file
IMDb_Names_df.to_csv(resources_folder + 'clean_Names.csv', index=False)
